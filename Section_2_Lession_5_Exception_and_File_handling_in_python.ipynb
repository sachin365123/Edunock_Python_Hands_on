# %%
import os

# %%
f=open("/content/sample_data/Francis Galton Regression Data.txt")

# %%
f=open("/content/sample_data/Francis Galton Regression Data.txt","r")
print(f.read())
# Out:
# Family	Father	Mother	Gender	Height	Kids
# 1	78.5	67	M	73.2	4
# 1	78.5	67	F	69.2	4
# 1	78.5	67	F	69	4
# 1	78.5	67	F	69	4
# 2	75.5	66.5	M	73.5	4
# 2	75.5	66.5	M	72.5	4
# 2	75.5	66.5	F	65.5	4
# 2	75.5	66.5	F	65.5	4
# 3	75	64	M	71	2
# 3	75	64	F	68	2
# 4	75	64	M	70.5	5
# 4	75	64	M	68.5	5
# 4	75	64	F	67	5
# 4	75	64	F	64.5	5
# 4	75	64	F	63	5
# 5	75	58.5	M	72	6
# 5	75	58.5	M	69	6
# 5	75	58.5	M	68	6
# 5	75	58.5	F	66.5	6
# 5	75	58.5	F	62.5	6
# 5	75	58.5	F	62.5	6
# 6	74	68	F	69.5	1
# 7	74	68	M	76.5	6
# 7	74	68	M	74	6
# 7	74	68	M	73	6
# 7	74	68	M	73	6
# 7	74	68	F	70.5	6
# 7	74	68	F	64	6
# 8	74	66.5	F	70.5	3
# 8	74	66.5	F	68	3
# 8	74	66.5	F	66	3
# 9	74.5	66	F	66	1
# 10	74	65.5	F	65.5	1
# 11	74	62	M	74	8
# 11	74	62	M	70	8
# 11	74	62	F	68	8
# 11	74	62	F	67	8
# 11	74	62	F	67	8
# 11	74	62	F	66	8
# 11	74	62	F	63.5	8
# 11	74	62	F	63	8
# 12	74	61	F	65	1
# 14	73	67	M	68	2
# 14	73	67	M	67	2
# 15	73	66.5	M	71	3
# 15	73	66.5	M	70.5	3
# 15	73	66.5	F	66.7	3
# 16	73	65	M	72	9
# 16	73	65	M	70.5	9
# ...

# %%
f=open("/content/sample_data/Francis Galton Regression Data.txt","r")
print(f.read())
print(f.read())
# Out:
# Family	Father	Mother	Gender	Height	Kids
# 1	78.5	67	M	73.2	4
# 1	78.5	67	F	69.2	4
# 1	78.5	67	F	69	4
# 1	78.5	67	F	69	4
# 2	75.5	66.5	M	73.5	4
# 2	75.5	66.5	M	72.5	4
# 2	75.5	66.5	F	65.5	4
# 2	75.5	66.5	F	65.5	4
# 3	75	64	M	71	2
# 3	75	64	F	68	2
# 4	75	64	M	70.5	5
# 4	75	64	M	68.5	5
# 4	75	64	F	67	5
# 4	75	64	F	64.5	5
# 4	75	64	F	63	5
# 5	75	58.5	M	72	6
# 5	75	58.5	M	69	6
# 5	75	58.5	M	68	6
# 5	75	58.5	F	66.5	6
# 5	75	58.5	F	62.5	6
# 5	75	58.5	F	62.5	6
# 6	74	68	F	69.5	1
# 7	74	68	M	76.5	6
# 7	74	68	M	74	6
# 7	74	68	M	73	6
# 7	74	68	M	73	6
# 7	74	68	F	70.5	6
# 7	74	68	F	64	6
# 8	74	66.5	F	70.5	3
# 8	74	66.5	F	68	3
# 8	74	66.5	F	66	3
# 9	74.5	66	F	66	1
# 10	74	65.5	F	65.5	1
# 11	74	62	M	74	8
# 11	74	62	M	70	8
# 11	74	62	F	68	8
# 11	74	62	F	67	8
# 11	74	62	F	67	8
# 11	74	62	F	66	8
# 11	74	62	F	63.5	8
# 11	74	62	F	63	8
# 12	74	61	F	65	1
# 14	73	67	M	68	2
# 14	73	67	M	67	2
# 15	73	66.5	M	71	3
# 15	73	66.5	M	70.5	3
# 15	73	66.5	F	66.7	3
# 16	73	65	M	72	9
# 16	73	65	M	70.5	9
# ...

# %%
f=open("/content/sample_data/Francis Galton Regression Data.txt","r")
print(f.readline())
print(f.readline())
# Out:
# Family	Father	Mother	Gender	Height	Kids
#
# 1	78.5	67	M	73.2	4

# %%
f=open("/content/sample_data/Francis Galton Regression Data.txt","a")
f.write("My course is data science")
f.close()

f=open("/content/sample_data/Francis Galton Regression Data.txt","r")
print(f.read())
# Out:
# Family	Father	Mother	Gender	Height	Kids
# 1	78.5	67	M	73.2	4
# 1	78.5	67	F	69.2	4
# 1	78.5	67	F	69	4
# 1	78.5	67	F	69	4
# 2	75.5	66.5	M	73.5	4
# 2	75.5	66.5	M	72.5	4
# 2	75.5	66.5	F	65.5	4
# 2	75.5	66.5	F	65.5	4
# 3	75	64	M	71	2
# 3	75	64	F	68	2
# 4	75	64	M	70.5	5
# 4	75	64	M	68.5	5
# 4	75	64	F	67	5
# 4	75	64	F	64.5	5
# 4	75	64	F	63	5
# 5	75	58.5	M	72	6
# 5	75	58.5	M	69	6
# 5	75	58.5	M	68	6
# 5	75	58.5	F	66.5	6
# 5	75	58.5	F	62.5	6
# 5	75	58.5	F	62.5	6
# 6	74	68	F	69.5	1
# 7	74	68	M	76.5	6
# 7	74	68	M	74	6
# 7	74	68	M	73	6
# 7	74	68	M	73	6
# 7	74	68	F	70.5	6
# 7	74	68	F	64	6
# 8	74	66.5	F	70.5	3
# 8	74	66.5	F	68	3
# 8	74	66.5	F	66	3
# 9	74.5	66	F	66	1
# 10	74	65.5	F	65.5	1
# 11	74	62	M	74	8
# 11	74	62	M	70	8
# 11	74	62	F	68	8
# 11	74	62	F	67	8
# 11	74	62	F	67	8
# 11	74	62	F	66	8
# 11	74	62	F	63.5	8
# 11	74	62	F	63	8
# 12	74	61	F	65	1
# 14	73	67	M	68	2
# 14	73	67	M	67	2
# 15	73	66.5	M	71	3
# 15	73	66.5	M	70.5	3
# 15	73	66.5	F	66.7	3
# 16	73	65	M	72	9
# 16	73	65	M	70.5	9
# ...

# %%
f=open("/content/sample_data/Francis Galton Regression Data.txt","w")
f.write("Woops it's not there")
f.close()

# %%
# Exception handling in python

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-13-9e1622b385b6> in <module>()
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
i=0
j=10/i
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-14-c3e5493f4952> in <module>()
#       1 i=0
# ----> 2 j=10/i
#
# ZeroDivisionError: division by zero

# %%
2+'2'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-ccd69389b8cc> in <module>()
# ----> 1 2+'2'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
value=[2,'4']
sum(value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-cfe43c935d2e> in <module>()
#       1 value=[2,'4']
# ----> 2 sum(value)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
  i=0
  j=10/i
except:
  print("Edunock Exception")
  j=0
print("ERP")
# Out:
# Edunock Exception
# ERP

# %%
#Handling multiple errors
try:
  i=0
  j=10/i
  value=[1,'5']
  print("Multiple error")
except TypeError:
  print("Sachin")
  j=0
except ZeroDivisionError:
  print("Zero error")
  j=0
print("Delhi")
print("New Noida")
# Out:
# Zero error
# Delhi
# New Noida
